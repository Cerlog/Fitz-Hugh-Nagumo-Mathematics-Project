# %%
from scipy.integrate import odeint
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.legend import Legend

# %%
a1 = -0.1
e1 = 0.01
b1 = 2

# %%
params=[e1]
ms = 500
timesteps = 1000000


def fhn(x, t, params):
    # constants

    V1 = x[0]
    W1 = x[1]

    e1 = params[0]

    dV1dt = (V1 * (a1 - V1) * (V1 - 1) - W1)
    dW1dt = (e1 * (V1 - b1 * W1))
    return [dV1dt,dW1dt]


x0 = [0.1,0] # initial conditions
t = np.linspace(0,ms,timesteps) # time
x = odeint(fhn,x0,t, args=(params,))

V1 = x[:,0]
W1 = x[:,1]

# %%
params = [0.01] # alpha
x1 = odeint(fhn, x0, t,args=(params,))

params = [0.011] # alpha
x2 = odeint(fhn, x0, t,args=(params,))

params = [0.009] # alpha
x3 = odeint(fhn, x0, t,args=(params,))

f, (ax1) = plt.subplots(figsize=(10,8))
f.suptitle(r'Pertubating of the $\alpha$ parameter', fontsize=16)
line0, = ax1.plot(t, x1[:,0], color = "b", label = r"$\epsilon$ = 0.01")
line1, = ax1.plot(t, x2[:,0], color = "r", label = r"$\epsilon$ = 0.011")
line2, = ax1.plot(t, x3[:,0], color = "c", label = r"$\epsilon$ = 0.009")
ax1.set_xlabel('Time (ms)', fontsize =14)
ax1.set_ylabel('Voltage (mV)', fontsize =14)
ax1.tick_params(labelsize=13)
ax1.set_yticks([-0.5, -1, 0, 0.5, 1, 1])
ax1.grid(linestyle='--', linewidth=0.5)
ax1.grid(linestyle='--', linewidth=0.5)
leg = plt.legend(bbox_to_anchor=(0.85,0.5), loc="center left", fontsize =14, borderaxespad=6.5)
f.savefig('Beta_pertubated_10_percent.jpeg', dpi=300, bbox_inches="tight")

# %%
e_0_01 = x1[:,0]

# %%
e_0_011 = x2[:,0]

# %%
e_0_009 = x2[:,0]

# %%
def find_max_min_index(list1, range):
    range
    MaxFromList = list1.max()
    MinFromList = list1.min()
    IndexOfMax = np.where(list1 == np.max(list1))
    IndexOfMin = np.where(list1 == np.min(list1))
    print(f"The maximum value is {MaxFromList}, with index of {IndexOfMax} and minimum value {MinFromList}, with index of {IndexOfMin} in a {range} range")

# %%
#Epsillon = 0.01

# %%
V1_epsilon_0_01 = x1[:,0]
range1 = "0-100"
V1_epsilon_0_01_range_0_100 = x1[0:100]
find_max_min_index(V1_epsilon_0_01_range_0_100, range1)
# Out:
# The maximum value is 0.10089531126305368, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range

# %%
V1_epsilon_0_01 = x1[:,0]
range2 = "100-200"
V1_epsilon_0_01_range_100_200 = x1[100:200]
find_max_min_index(V1_epsilon_0_01_range_100_200, range2)
# Out:
# The maximum value is 0.10180851029174026, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.020071570332288e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range

# %%
V1_epsilon_0_01 = x1[:,0]
range3 = "200-300"
V1_epsilon_0_01_range_200_300 = x1[200:300]
find_max_min_index(V1_epsilon_0_01_range_200_300, range3)
# Out:
# The maximum value is 0.1027307396099782, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0001008054455460033, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-300 range

# %%
V1_epsilon_0_01 = x1[:,0]
range4 = "300-450"
V1_epsilon_0_01_range_300_450 = x1[300:450]
find_max_min_index(V1_epsilon_0_01_range_300_450, range4)
# Out:
# The maximum value is 0.10413133332393212, with index of (array([149], dtype=int64), array([0], dtype=int64)) and minimum value 0.00015181826330083845, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 300-450 range

# %%
t[246] - t[129]
# Out:
# 0.0585000585000585

# %%
V1_epsilon_0_01[129]
# Out:
# 0.10116833130217923

# %%
V1_epsilon_0_01[246]
# Out:
# 0.10224082456676331

# %%
#Epsillon = 0.011

# %%
V1_epsilon_0_011 = x2[:,0]
range1 = "0-100"
V1_epsilon_0_011_range_0_100 = x2[0:100]
find_max_min_index(V1_epsilon_0_011_range_0_100, range1)
# Out:
# The maximum value is 0.10089518796131067, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range

# %%
V1_epsilon_0_011 = x2[:,0]
range2 = "100-200"
V1_epsilon_0_011_range_100_200 = x2[100:200]
find_max_min_index(V1_epsilon_0_011_range_100_200, range2)
# Out:
# The maximum value is 0.10180800883349102, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.521800790080286e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range

# %%
V1_epsilon_0_011 = x2[:,0]
range3 = "200-300"
V1_epsilon_0_011_range_200_300 = x2[200:300]
find_max_min_index(V1_epsilon_0_011_range_200_300, range3)
# Out:
# The maximum value is 0.10272960010759452, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.00011087475417467593, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-300 range

# %%
V1_epsilon_0_011 = x2[:,0]
range4 = "300-400"
V1_epsilon_0_011_range_300_400 = x2[300:400]
find_max_min_index(V1_epsilon_0_011_range_300_400, range4)
# Out:
# The maximum value is 0.10366010163098481, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0001669745400879827, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 300-400 range

# %%
V1_epsilon_0_011 = x2[:,0]
range4 = "400-500"
V1_epsilon_0_011_range_400_500 = x2[400:500]
find_max_min_index(V1_epsilon_0_011_range_400_500, range4)
# Out:
# The maximum value is 0.10459965601092669, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0002235217393422482, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 400-500 range

# %%
V1_epsilon_0_011[121]
# Out:
# 0.10109526307414851

# %%
V1_epsilon_0_011[230]
# Out:
# 0.10209275765691883

# %%
t[230] - t[121]
# Out:
# 0.054500054500054504

# %%
#Epsillon = 0.009

# %%
V1_epsilon_0_009 = x3[:,0]
range1 = "0-100"
V1_epsilon_0_009_range_0_100 = x3[0:100]
find_max_min_index(V1_epsilon_0_009_range_0_100, range1)
# Out:
# The maximum value is 0.10089543457297379, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range

# %%
V1_epsilon_0_009 = x3[:,0]
range2 = "100-200"
V1_epsilon_0_009_range_100_200 = x3[100:200]
find_max_min_index(V1_epsilon_0_009_range_100_200, range2)
# Out:
# The maximum value is 0.10180901181711499, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 4.5182918317518344e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range

# %%
V1_epsilon_0_009 = x3[:,0]
range3 = "200-350"
V1_epsilon_0_009_range_200_350 = x3[200:350]
find_max_min_index(V1_epsilon_0_009_range_200_350, range3)
# Out:
# The maximum value is 0.10319684377761633, with index of (array([149], dtype=int64), array([0], dtype=int64)) and minimum value 9.073409525590924e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-350 range

# %%
V1_epsilon_0_009 = x3[:,0]
range4 = "350-500"
V1_epsilon_0_009_range_350_500 = x3[350:500]
find_max_min_index(V1_epsilon_0_009_range_350_500, range4)
# Out:
# The maximum value is 0.10460608897662953, with index of (array([149], dtype=int64), array([0], dtype=int64)) and minimum value 0.0001597597075613644, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 350-500 range

# %%
t[266] - t[139]
# Out:
# 0.0635000635000635

# %%
params = [0.01]  # alpha
y1 = odeint(fhn, x0, t, args=(params,))

params = [0.0175]  #alpha
y2 = odeint(fhn, x0, t, args=(params,))

#params = [0.005]  #alpha
#y3 = odeint(fhn, x0, t, args=(params,))

params = [0.0025]  #alpha
x3 = odeint(fhn, x0, t, args=(params,))

f, (ax1) = plt.subplots(figsize=(10,8))
f.suptitle(r'Pertubating of the $\alpha$ parameter', fontsize=16)
line0, = ax1.plot(t, y1[:, 0], color="b", label=r"$\epsilon$ = 0.01")

line1, = ax1.plot(t, y2[:, 0], color="r", label=r"$\epsilon$ = 0.005")

line2, = ax1.plot(t, x3[:, 0], color="c", label=r"$\epsilon$ = 0.1")
ax1.set_xlabel('Time (ms)', fontsize =14)
ax1.set_ylabel('Voltage (mV)', fontsize =14)
ax1.tick_params(labelsize=13)
#ax1.set_xticklabels(group_labels)
ax1.grid(linestyle='--', linewidth=0.5)
ax1.grid(linestyle='--', linewidth=0.5)
leg = plt.legend(bbox_to_anchor=(0.85,0.5), loc="center left", fontsize =14, borderaxespad=6.5)
f.savefig('Alpha_pertubated_10_percent.jpeg', dpi=300, bbox_inches="tight")

# %%
#Epsillon = 0.009

# %%
V1_epsilon_0_005 = y2[:,0]
range1 = "0-100"
V1_epsilon_0_005_range_0_100 = y2[0:100]
find_max_min_index(V1_epsilon_0_009_range_0_100, range1)
# Out:
# The maximum value is 0.10089543457297379, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range

# %%
V1_epsilon_0_005 = y2[:,0]
range2 = "100-300"
V1_epsilon_0_005_range_100_300 = y2[100:300]
find_max_min_index(V1_epsilon_0_005_range_100_300, range2)
# Out:
# The maximum value is 0.1027221989491441, with index of (array([199], dtype=int64), array([0], dtype=int64)) and minimum value 8.781809672102638e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-300 range

# %%
V1_epsilon_0_005 = y2[:,0]
range3 = "300-500"
V1_epsilon_0_005_range_300_500 = y2[300:500]
find_max_min_index(V1_epsilon_0_005_range_300_500, range3)
# Out:
# The maximum value is 0.10457877906242533, with index of (array([199], dtype=int64), array([0], dtype=int64)) and minimum value 0.000265377308305827, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 300-500 range
