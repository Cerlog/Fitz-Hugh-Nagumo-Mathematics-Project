# %%
from scipy.integrate import odeint
import numpy as np
from matplotlib import pyplot as plt

# %%
def find_max_min_index(list1, range): # function for finding max and min amplitude
    range
    MaxFromList = list1.max()
    MinFromList = list1.min()
    IndexOfMax = np.where(list1 == np.max(list1))
    IndexOfMin = np.where(list1 == np.min(list1))
    print(f"The maximum value is {MaxFromList}, with index of {IndexOfMax} and minimum value {MinFromList}, with index of {IndexOfMin} in a {range} range")

# %%
def find_period_amplitude_and_frequency(min, max, period):
    amplitude = max + abs(min)
    period_to_seconds = period /1000
    frequency = 1/period_to_seconds
    print(f"The amplitude =  {amplitude}, the period = {period_to_seconds} and the frequency = {frequency}")

# %%
a1 = -0.1
e1 = 0.01
b1 = 2

# %%
params=[a1]
ms = 500
timesteps = 1000000


def fhn(x, t, params):
    # constants

    V1 = x[0]
    W1 = x[1]

    a1 = params[0]

    dV1dt = (V1 * (a1 - V1) * (V1 - 1) - W1)
    dW1dt = (e1 * (V1 - b1 * W1))
    return [dV1dt,dW1dt]


x0 = [0.1,0] # initial conditions
t = np.linspace(0,ms,timesteps) # time
x = odeint(fhn,x0,t, args=(params,))

V1 = x[:,0]
W1 = x[:,1]

# %%
params = [-0.1] # alpha
x1 = odeint(fhn, x0, t,args=(params,))

params = [-0.09] #alpha
x2 = odeint(fhn, x0, t,args=(params,))

params = [-0.11] #alpha
x3 = odeint(fhn, x0, t,args=(params,))


f, (ax1) = plt.subplots(figsize=(10,8))
line0, = ax1.plot(t, x1[:,0], color = "#0000ff", label = r"$\alpha$ = -0.1")
f.suptitle(r'Pertubating of the $\alpha$ parameter', fontsize=16)

line1, = ax1.plot(t, x2[:,0], color = "#66cc00", label = r"$\alpha$ = -0.025")
line2, = ax1.plot(t, x3[:,0], color = "#ff0000", label = r"$\alpha$ = -0.175")
ax1.set_yticks([-0.5, -0.5, 0, 0.5, 1, 1])
ax1.set_xlabel('Time (ms)', fontsize =14)
ax1.set_ylabel('Voltage (mV)', fontsize =14)
ax1.tick_params(labelsize=13)
ax1.grid(linestyle='--', linewidth=0.5)
ax1.grid(linestyle='--', linewidth=0.5)
leg = plt.legend(bbox_to_anchor=(0.85,0.5), loc="center left", fontsize =14, borderaxespad=6.5)
f.savefig('Alpha_pertubated_75_percent.jpeg', dpi=300, bbox_inches="tight")

# %%
a_0_1 = x1[:,0]
a_0_025 = x2[:,0]
a_0_175 = x3[:,0]

# %% [markdown]
# Finding the min and max value for the V1, where $\alpha = -0.1$

# %%
V1_alpha_0_1 = x1[:, 0] # define list containing values for the V1, where Alpha = -0.1

# %%
range1 = "0-100"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_1_range_0_100 = x1[0:100]
find_max_min_index(V1_Alpha_0_1_range_0_100, range1)
# Out:
# The maximum value is 0.10089531126305368, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range

# %%
range2 = "100-200"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_1_range_100_200 = x1[100:200]
find_max_min_index(V1_Alpha_0_1_range_100_200, range2)
# Out:
# The maximum value is 0.10180851029174026, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.020071570332288e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range

# %%
range3 = "200-300"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_1_range_200_300 = x1[200:300]
find_max_min_index(V1_Alpha_0_1_range_200_300, range3)
# Out:
# The maximum value is 0.1027307396099782, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0001008054455460033, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-300 range

# %%
range4 = "300-400"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_1_range_300_400 = x1[300:420]
find_max_min_index(V1_Alpha_0_1_range_300_400, range4)
# Out:
# The maximum value is 0.10384953911773233, with index of (array([119], dtype=int64), array([0], dtype=int64)) and minimum value 0.00015181826330083845, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 300-400 range

# %%
range5 = "400-500"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_1_range_400_500 = x1[400:500]
find_max_min_index(V1_Alpha_0_1_range_400_500, range5)
# Out:
# The maximum value is 0.1046028719468335, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0002032433114005855, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 400-500 range

# %%
#V1_alpha_0_1[129] # calculating the period for alpha = -0.1, in the interval 100-300

t[246] - t[129]
# Out:
# 0.0585000585000585

# %% [markdown]
# Amplitude when Alpha = -0.6 =  1.744
#
# Period = 180.360 ms = 0.180 seconds
#
# Frequency = 1/0.180 = 5,555

# %%
params = [-0.1]  # alpha
x1 = odeint(fhn, x0, t, args=(params,))

#params = [-0.6]  #alpha
#x2 = odeint(fhn, x0, t, args=(params,))

params = [-0.09]  #alpha

x3 = odeint(fhn, x0, t, args=(params,))

params = [-0.11]  #alpha

x4 = odeint(fhn, x0, t, args=(params,))

params = [-0.019]  #alpha

x5 = odeint(fhn, x0, t, args=(params,))


f, (ax1) = plt.subplots(figsize=(10,8))
line0, = ax1.plot(t, x1[:, 0], color="b", label=r"$\alpha$ = -0.1")
f.suptitle(r'Pertubating of the $\alpha$ parameter', fontsize=16)
#line1, = ax1.plot(t, x3[:, 0], 'r-', label=r"$\alpha$ = -0.6")

line2, = ax1.plot(t, x4[:, 0], color="r", label=r"$\alpha$ = -0.09")


line4, = ax1.plot(t, x4[:, 0], color="m", label=r"$\alpha$ = -0.11")

#line3, = ax1.plot(t, x5[:, 0], color="c", label=r"$\alpha$ =  -0.016")
ax1.set_xlabel('Time (ms)', fontsize =14)
ax1.set_ylabel('Voltage (mV)', fontsize =14)
ax1.tick_params(labelsize=13)
#ax1.set_yticks([-0.5, -0.5, 0, 0.5, 1, 1])
#ax1.set_xticklabels(group_labels)
ax1.grid(linestyle='--', linewidth=0.5)
ax1.grid(linestyle='--', linewidth=0.5)
leg = plt.legend(bbox_to_anchor=(0.85,0.5), loc="center left", fontsize =14, borderaxespad=6.5)
f.savefig('Alpha_pertubated_500_percent.jpeg', dpi=300, bbox_inches="tight")

# %%
alpha_0_1 = x1[:, 0]
alpha_0_09 = x3[:, 0]
alpha_0_11 = x4[:,0]

# %%
distanceBetween_a_0_1_and_alpha_0_09 = L2Distance(alpha_0_1, alpha_0_09)
distanceBetween_a_0_1_and_alpha_0_11 = L2Distance(alpha_0_1,alpha_0_11)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [74], in <module>
# ----> 1 distanceBetween_a_0_1_and_alpha_0_09 = L2Distance(alpha_0_1, alpha_0_09)
#       2 distanceBetween_a_0_1_and_alpha_0_11 = L2Distance(alpha_0_1,alpha_0_11)
#
# NameError: name 'L2Distance' is not defined

# %%
distanceBetween_a_0_1_and_alpha_0_09

# %%
distanceBetween_a_0_1_and_alpha_0_11

# %%
#V1_alpha_0_6[7]
t[7] - t[187]

# %% [markdown]
# | Interval | Min Value | Max Value |
# |----------|------|-----------|
# | 0 - 150  | 0.974 | -0.770      |
# | 150-350  |1.046 |  -0.769|
# | 350-500  |  1.046   |  -0.769        |

# %%
V1_alpha_0_6 = x2[:, 0] # define list containing values for the V1, where Alpha = -0.6

# %%
range1_1 = "0-150"
V1_Alpha_0_6_range_0_150 = x2[0:150]
find_max_min_index(V1_Alpha_0_6_range_0_150, range1_1)

# %%
range1_2 = "150-350"
V1_Alpha_0_6_range_150_350 = x2[150:350]
find_max_min_index(V1_Alpha_0_6_range_150_350, range1_2)

# %%
range1_3 = "350-500"
V1_Alpha_0_6_range_350_500 = x2[350:500]
find_max_min_index(V1_Alpha_0_6_range_150_350, range1_2)

# %% [markdown]
# Alpha = -0.09

# %%
#Alpha = -0.09

V1_alpha_0_09 = x3[:, 0]  # define list containing values for the V1, where Alpha = -0.9
range1 = "0-100"
V1_Alpha_0_09_range_0_100 = x3[0:100]
find_max_min_index(V1_Alpha_0_09_range_0_100, range1)

range2 = "100-200"
V1_Alpha_0_09_range_100_200 = x3[100:200]
find_max_min_index(V1_Alpha_0_09_range_100_200, range2)
#V1_alpha_0_1[129]

range3 = "200-300"
V1_Alpha_0_09_range_200_300 = x3[200:300]
find_max_min_index(V1_Alpha_0_09_range_200_300, range3)

range4 = "300-400"
V1_Alpha_0_09_range_300_400 = x3[300:420]
find_max_min_index(V1_Alpha_0_09_range_300_400, range4)

range5 = "400-500"
V1_Alpha_0_09_range_400_500 = x3[400:500]
find_max_min_index(V1_Alpha_0_09_range_400_500, range5)
# Out:
# The maximum value is 0.10085031514860765, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range
# The maximum value is 0.10171714621849011, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.018939369986764e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range
# The maximum value is 0.10259206775226594, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0001007598668812826, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-300 range
# The maximum value is 0.10365283145997368, with index of (array([119], dtype=int64), array([0], dtype=int64)) and minimum value 0.00015171505102036403, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 300-400 range
# The maximum value is 0.10436669115147322, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0002030586374997762, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 400-500 range

# %%
#V1_alpha_0_09[130]

t[248] - t[130]
# Out:
# 0.059000059000059

# %%
x3[:,0][248]
# Out:
# 0.10214483906543528

# %%
x3[:,0][130]
# Out:
# 0.10111817503443513

# %% [markdown]
# Amplitude when Alpha = -0.09 =  1.331
#
# Period = 117 ms = 0.117 seconds
#
# Frequency = 1/0.117 = 8,547

# %% [markdown]
# | Interval | Max Value | Min Value |
# |----------|-----------|-----------|
# | 0 - 100  | 0.939     | -0.392    |
# | 100-200  | 0.947     | -0.391    |
# | 200-300  | 0.947     | -0.391    |
# | 300-420  | 0.947     | -0.392    |
# | 400-500  | 0.947     | -0.392    |

# %% [markdown]
# Alpha = -0.11

# %%
V1_alpha_0_11 = x4[:, 0]  # define list containing values for the V1, where Alpha = -0.9
range1 = "0-100"
V1_Alpha_0_09_range_0_100 = x4[0:100]
find_max_min_index(V1_Alpha_0_09_range_0_100, range1)

range2 = "100-200"
V1_Alpha_0_09_range_100_200 = x4[100:200]
find_max_min_index(V1_Alpha_0_09_range_100_200, range2)
#V1_alpha_0_1[129]

range3 = "200-300"
V1_Alpha_0_09_range_200_300 = x4[200:300]
find_max_min_index(V1_Alpha_0_09_range_200_300, range3)

range4 = "300-400"
V1_Alpha_0_09_range_300_400 = x4[300:420]
find_max_min_index(V1_Alpha_0_09_range_300_400, range4)

range5 = "400-500"
V1_Alpha_0_09_range_400_500 = x4[400:500]
find_max_min_index(V1_Alpha_0_09_range_400_500, range5)
# Out:
# The maximum value is 0.10094032522620215, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range
# The maximum value is 0.10189994733997176, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.021204073359668e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range
# The maximum value is 0.1028695781774493, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0001008510486296297, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-300 range
# The maximum value is 0.10404657886451249, with index of (array([119], dtype=int64), array([0], dtype=int64)) and minimum value 0.0001519215587031616, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 300-400 range
# The maximum value is 0.10483952827652823, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.00020342818404757093, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 400-500 range

# %%
t[245]-t[128]
# Out:
# 0.0585000585000585

# %%
#V1_alpha_0_11[128]
V1_alpha_0_11[13]
# Out:
# 0.10012293206417575

# %%
V1_alpha_0_11[245]
# Out:
# 0.1023447245622766

# %% [markdown]
# Amplitude
# when
# Alpha = -0.11 = 1.358
#
# Period = 115
# ms = 0.155
# seconds
#
# Frequency = 1 / 0.117 = 8,695

# %% [markdown]
# | Interval | Max
# Value | Min
# Value |
# | ---------- | ----------- | ----------- |
# | 0 - 100 |  0.942 | -0.404 |
# | 100 - 200 | 0.953 | -0.405 |
# | 200 - 300 | 0.953 | -0.405 |
# | 300 - 420 | 0.952 | -0.404 |
# | 400 - 500 |0.953 | -0.404 |

# %%
#Alpha = -0.016

V1_alpha_0_11 = x5[:, 0]  # define list containing values for the V1, where Alpha = -0.9
range1 = "0-100"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_09_range_0_100 = x5[0:100]
find_max_min_index(V1_Alpha_0_09_range_0_100, range1)
range2 = "100-200"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_09_range_100_200 = x5[100:200]
find_max_min_index(V1_Alpha_0_09_range_100_200, range2)
#V1_alpha_0_1[129]

range3 = "200-300"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_09_range_200_300 = x5[200:300]
find_max_min_index(V1_Alpha_0_09_range_100_200, range3)
range4 = "300-400"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_09_range_300_400 = x5[300:420]
find_max_min_index(V1_Alpha_0_09_range_300_400, range4)
range5 = "400-500"
#V1_alpha_0_1 = x1[:, 0]
V1_Alpha_0_09_range_400_500 = x5[400:500]
find_max_min_index(V1_Alpha_0_09_range_400_500, range5)
# Out:
# The maximum value is 0.10053135553164509, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range
# The maximum value is 0.10107055604351169, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.010909445191469e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range
# The maximum value is 0.10107055604351169, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.010909445191469e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-300 range
# The maximum value is 0.10226572125187429, with index of (array([119], dtype=int64), array([0], dtype=int64)) and minimum value 0.0001509846292793791, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 300-400 range
# The maximum value is 0.10270342165644018, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.00020175315269454152, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 400-500 range

# %% [markdown]
# Amplitude
# when
# Alpha = -0.11 = 1.358
#
# Period = 115
# ms = 0.155
# seconds
#
# Frequency = 1 / 0.117 = 8, 695

# %% [markdown]
# | Interval | Max
# Value | Min
# Value |
# | ---------- | ----------- | ----------- |
# | 0 - 100 | 0.942 | -0.404 |
# | 100 - 200 | 0.953 | -0.405 |
# | 200 - 300 | 0.953 | -0.405 |
# | 300 - 420 | 0.952 | -0.404 |
# | 400 - 500 | 0.953 | -0.404 |

# %%
params = [-0.1]  # alpha
x1 = odeint(fhn, x0, t, args=(params,))

params = [-0.025]  #alpha
x2 = odeint(fhn, x0, t, args=(params,))

params = [-0.175]  #alpha

x3 = odeint(fhn, x0, t, args=(params,))


f, (ax1) = plt.subplots(figsize=(10,8))
line0, = ax1.plot(t, x1[:, 0], color="b", label=r"$\alpha$ = -0.1")
f.suptitle(r'Pertubating of the $\alpha$ parameter', fontsize=16)
line1, = ax1.plot(t, x2[:, 0], 'r-', label=r"$\alpha$ = -0.025")

line2, = ax1.plot(t, x3[:, 0], color="c",label=r"$\alpha$ =-0.175")


ax1.set_xlabel('Time (ms)', fontsize =14)
ax1.set_ylabel('Voltage (mV)', fontsize =14)
ax1.tick_params(labelsize=13)
ax1.set_yticks([-0.5, -1, 0, 0.5, 1, 1])
ax1.grid(linestyle='--', linewidth=0.5)
ax1.grid(linestyle='--', linewidth=0.5)
leg = plt.legend(bbox_to_anchor=(0.85,0.5), loc="center left", fontsize =14, borderaxespad=6.5)
f.savefig('Alpha_pertubated_75_percent.jpeg', dpi=300, bbox_inches="tight")

# %%
#-0.025

# %%
V1_Alpha_0_025 = x2[:,0]
range1 = "0-100"
V1_Alpha_0_025_range_0_100 = x2[0:100]
find_max_min_index(V1_Alpha_0_025_range_0_100, range1)
# Out:
# The maximum value is 0.10055827511541168, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range

# %%
range2 = "100-200"
V1_Alpha_0_025_range_100_200 = x2[100:200]
find_max_min_index(V1_Alpha_0_025_range_100_200, range2)
# Out:
# The maximum value is 0.10112505561718299, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.011587440892923e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range

# %%
range3 = "200-350"
V1_Alpha_0_025_range_200_350 = x2[200:350]
find_max_min_index(V1_Alpha_0_025_range_200_350, range3)
# Out:
# The maximum value is 0.10198070988264585, with index of (array([149], dtype=int64), array([0], dtype=int64)) and minimum value 0.00010046420003625669, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-350 range

# %%
range4 = "350-500"
V1_Alpha_0_025_range_350_500 = x2[350:500]
find_max_min_index(V1_Alpha_0_025_range_350_500,range4)
# Out:
# The maximum value is 0.10284305975491077, with index of (array([149], dtype=int64), array([0], dtype=int64)) and minimum value 0.00017642520093244128, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 350-500 range

# %%
t[281]-t[149] # period
# Out:
# 0.06600006600006601

# %%
#Alpha = -0.175

# %%
V1_Alpha_0_175 = x3[:,0]

# %%
V1_Alpha_0_175_range_0_100 = x3[0:100]
find_max_min_index(V1_Alpha_0_175_range_0_100, range1)
# Out:
# The maximum value is 0.10123335140010759, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 0.0, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 0-100 range

# %%
V1_Alpha_0_175_range_100_200 = x3[100:200]
find_max_min_index(V1_Alpha_0_175_range_100_200, range2)
# Out:
# The maximum value is 0.10249606980736906, with index of (array([99], dtype=int64), array([0], dtype=int64)) and minimum value 5.0285727256219205e-05, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 100-200 range

# %%
V1_Alpha_0_175_range_200_350 = x3[200:350]
find_max_min_index(V1_Alpha_0_175_range_200_350, range3)
# Out:
# The maximum value is 0.10442271388349199, with index of (array([149], dtype=int64), array([0], dtype=int64)) and minimum value 0.00010114806461872586, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 200-350 range

# %%
V1_Alpha_0_175_range_350_500 = x3[350:500]
find_max_min_index(V1_Alpha_0_175_range_350_500, range4)
# Out:
# The maximum value is 0.1063894328720544, with index of (array([149], dtype=int64), array([0], dtype=int64)) and minimum value 0.00017854025003789074, with index of (array([0], dtype=int64), array([1], dtype=int64)) in a 350-500 range

# %%
t[242] - t[126]
# Out:
# 0.058000058000058
