# %%
def f(c,x): return x*(c-x)*(x-1)

ax = plt.subplot(1,1,1)

c_data = []
x_data = []
for c in np.linspace(-50,50,20000):
    x = 0.1
    for i in range(1000):
        x = f(c,x)
    for i in range(1000):
        x = f(c,x)
        c_data.append(c)
        x_data.append(x)
plt.plot(c_data,x_data,'k.', alpha=0.2, markersize=0.3)



fig = ax.figure
fig.set_figwidth(13)
fig.set_figheight(8)
# Out:
# C:\Users\Petrb\AppData\Local\Temp\ipykernel_30296\3148660828.py:1: RuntimeWarning: overflow encountered in double_scalars
#   def f(c,x): return x*(c-x)*(x-1)
